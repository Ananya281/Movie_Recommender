# %%
import pickle
with open('movienew.pkl', 'rb') as f:
    movienew = pickle.load(f)

# %%
with open('similarity.pkl', 'rb') as f:
    similarity = pickle.load(f)

# %%
movienew
# Out:
#                                      title  \
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 2877                     Babul (1950 film)
# 2878                          Jogan (film)
# 2879                   Samadhi (1950 film)
# 2880                   Sangram (1950 film)
# 2881              Sheesh Mahal (1950 film)
#
#                                             poster_path year_of_release  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...            2019
# 1     https://upload.wikimedia.org/wikipedia/en/d/d3...            2019
# 2     https://upload.wikimedia.org/wikipedia/en/thum...            2019
# 3     https://upload.wikimedia.org/wikipedia/en/thum...            2019
# 4     https://upload.wikimedia.org/wikipedia/en/9/9e...            2018
# ...

# %%
similarity
# Out:
# array([[1.        , 0.27509852, 0.04722238, ..., 0.09985103, 0.        ,
#         0.00542837],
#        [0.27509852, 1.        , 0.05583282, ..., 0.10330048, 0.        ,
#         0.01283635],
#        [0.04722238, 0.05583282, 1.        , ..., 0.02381177, 0.09895656,
#         0.17605477],
#        ...,
#        [0.09985103, 0.10330048, 0.02381177, ..., 1.        , 0.04359213,
#         0.05474489],
#        [0.        , 0.        , 0.09895656, ..., 0.04359213, 1.        ,
#         0.25594636],
#        [0.00542837, 0.01283635, 0.17605477, ..., 0.05474489, 0.25594636,
#         1.        ]])

# %%
from pymongo import MongoClient
import pandas as pd

# %%
MONGO_URI = "mongodb+srv://admin:Ananya%402801@cluster0.jann4mj.mongodb.net/movie_recommender?retryWrites=true&w=majority&tls=true"
client = MongoClient(MONGO_URI)
db = client["movie_recommender"]
collection = db["histories"]

# %%
data = list(collection.find())
df = pd.DataFrame(data)

# %%
df = df.drop(columns=['__v'], errors='ignore')

# %%
df['user'] = df['user'].astype(str)

# %%
df
# Out:
#                          _id                      user  \
# 0   67fe2cbdbdb1ddbf225a31e5  67fcab79c055d149ee6dca27
# 1   67fe2cbdbdb1ddbf225a31e7  67fcab79c055d149ee6dca27
# 2   67fe2cf9bdb1ddbf225a31e9  67fcab79c055d149ee6dca27
# 3   67fe2cf9bdb1ddbf225a31eb  67fcab79c055d149ee6dca27
# 4   67fe2df5bdb1ddbf225a31ed  67fcab79c055d149ee6dca27
# ..                       ...                       ...
# 67  6804d815816bfb903302a4d2  67fcab79c055d149ee6dca27
# 68  6804d81b816bfb903302a4d5  67fcab79c055d149ee6dca27
# 69  6804d822816bfb903302a4d8  67fcab79c055d149ee6dca27
# 70  6804d829816bfb903302a4db  67fcab79c055d149ee6dca27
# 71  6804d832816bfb903302a4de  67fcab79c055d149ee6dca27
#
#                        title               timestamp
# 0           OMG – Oh My God! 2025-04-15 09:54:05.712
# 1           OMG – Oh My God! 2025-04-15 09:54:05.749
# 2   Uri: The Surgical Strike 2025-04-15 09:55:05.681
# 3   Uri: The Surgical Strike 2025-04-15 09:55:05.724
# ...

# %%
def recommend_based_movie(user_id, df, movienew, similarity):
    MONGO_URI = "mongodb+srv://admin:Ananya%402801@cluster0.jann4mj.mongodb.net/movie_recommender?retryWrites=true&w=majority&tls=true"
    client = MongoClient(MONGO_URI)
    db = client["movie_recommender"]
    collection = db["histories"]

    data = list(collection.find())
    item_item_df = pd.DataFrame(data)

    item_item_df = item_item_df.drop(columns=['_id','__v'], errors='ignore')

    item_item_df['user'] = item_item_df['user'].astype(str)
    
    # Step 1: Get the most recent movie watched by the user
    user_history = item_item_df[item_item_df['user'] == user_id]
    
    if user_history.empty:
        return []  # No history for this user

    # Sort by timestamp and get the latest movie
    user_history_sorted = user_history.sort_values(by='timestamp', ascending=False)
    recent_movie = user_history_sorted.iloc[0]['title']

    # Step 2: Normalize the recent movie title
    query_normalized = recent_movie.strip().lower()
    movie_titles_normalized = movienew['title'].str.lower().str.replace(r'\s*\(.*\)', '', regex=True)

    # Step 3: Find matching movie(s) in the database
    movie_matches = movienew[movie_titles_normalized.str.contains(query_normalized, na=False)]
    if movie_matches.empty:
        return []

    recommendations = []

    for _, row in movie_matches.iterrows():
        try:
            movie_index = movienew[movie_titles_normalized == row['title'].lower()].index[0]
            distances = similarity[movie_index]
            movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:6]

            for i in movies_list:
                movie_info = [
                    [movienew.iloc[i[0]]['title']],
                    [movienew.iloc[i[0]]['imdb_rating']],
                    [movienew.iloc[i[0]]['poster_path']]
                ]
                recommendations.append(movie_info)
        except IndexError:
            continue

    recommendations.sort(key=lambda x: x[1], reverse=True)
    return recommendations[:5]

# %%
user_id = '67fcab79c055d149ee6dca27'  # Replace with actual user ID
recommend_based_movie(user_id, df, movienew, similarity)
# Out:
# [[['Ghayal (1990 film)'],
#   [3.8],
#   ['https://upload.wikimedia.org/wikipedia/en/thumb/9/95/Ghayal%2C_1990_film.jpg/220px-Ghayal%2C_1990_film.jpg']],
#  [['Boy Friend (1961 film)'],
#   [3.65],
#   ['https://upload.wikimedia.org/wikipedia/en/thumb/7/7d/Boy_Friend_1961_film.jpg/220px-Boy_Friend_1961_film.jpg']],
#  [['Ilzaam'],
#   [3.1],
#   ['https://upload.wikimedia.org/wikipedia/en/thumb/e/ef/Ilzaam.jpg/220px-Ilzaam.jpg']],
#  [['Suhaag (1994 film)'],
#   [2.85],
#   ['https://upload.wikimedia.org/wikipedia/en/f/fe/Suhaag_Poster.jpg']],
#  [['All Rounder (1984 film)'],
#   [2.45],
#   ['https://upload.wikimedia.org/wikipedia/en/7/76/All_Rounder_1984_poster.png']]]
