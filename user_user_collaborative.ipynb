# %%
# ✅ Import libraries
from pymongo import MongoClient
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
# ✅ Connect to MongoDB Atlas
MONGO_URI = "mongodb+srv://admin:Ananya%402801@cluster0.jann4mj.mongodb.net/movie_recommender?retryWrites=true&w=majority&tls=true"
client = MongoClient(MONGO_URI)
db = client["movie_recommender"]
collection = db["histories"]

# %%
# ✅ Load data
data = list(collection.find())
df = pd.DataFrame(data)

# %%
# ✅ Drop irrelevant columns
df = df.drop(columns=['_id', 'timestamp', '__v'], errors='ignore')

# %%
# ✅ Convert ObjectId to string for 'user'
df['user'] = df['user'].astype(str)

# %%
df
# Out:
#                         user                        title
# 0   67fcab79c055d149ee6dca27             OMG – Oh My God!
# 1   67fcab79c055d149ee6dca27             OMG – Oh My God!
# 2   67fcab79c055d149ee6dca27     Uri: The Surgical Strike
# 3   67fcab79c055d149ee6dca27     Uri: The Surgical Strike
# 4   67fcab79c055d149ee6dca27     Black Friday (2007 film)
# 5   67fcab79c055d149ee6dca27     Black Friday (2007 film)
# 6   67fcab79c055d149ee6dca27                     Gol Maal
# 7   67fcab79c055d149ee6dca27                     Gol Maal
# 8   67fcab79c055d149ee6dca27           Jaane Bhi Do Yaaro
# 9   67fcab79c055d149ee6dca27           Jaane Bhi Do Yaaro
# 10  67fcab79c055d149ee6dca27               Ranchi Diaries
# 11  67fcab79c055d149ee6dca27               Ranchi Diaries
# 12  67fcab79c055d149ee6dca27    Love Marriage (1959 film)
# 13  67fcab79c055d149ee6dca27    Love Marriage (1959 film)
# 14  67fcab79c055d149ee6dca27    Love Marriage (1959 film)
# 15  67fcab79c055d149ee6dca27                    Marmayogi
# 16  67fcab79c055d149ee6dca27          Kuchh Bheege Alfaaz
# 17  67fcab79c055d149ee6dca27                      Chhalia
# 18  67fcab79c055d149ee6dca27                 Bhoot (film)
# 19  67fcab79c055d149ee6dca27                 Bhoot (film)
# 20  67fcab79c055d149ee6dca27                  Section 375
# 21  67fcab79c055d149ee6dca27                  Section 375
# 22  67fcab79c055d149ee6dca27                  Section 375
# 23  67fcab79c055d149ee6dca27              Dehraadun Diary
# 24  67fcab79c055d149ee6dca27                    Shamitabh
# 25  67fcab79c055d149ee6dca27                 Vishwaroopam
# 26  661eabc123abc123abc123aa                      Kahaani
# 27  661eabc123abc123abc123aa                       Masaan
# 28  661eabc123abc123abc123aa                       Talvar
# 29  661eabc123abc123abc123aa              Rang De Basanti
# 30  661eabc123abc123abc123aa                        Raazi
# 31  661eabc123abc123abc123aa                         Piku
# 32  661eabc123abc123abc123aa                      October
# 33  661eabc123abc123abc123aa                 Sardar Udham
# 34  661eabc123abc123abc123aa                          Uri
# 35  661eabc123abc123abc123aa                   Article 15
# 36  661eabc123abc123abc123bb                      Welcome
# 37  661eabc123abc123abc123bb                      Pathaan
# 38  661eabc123abc123abc123bb                         Beta
# 39  661eabc123abc123abc123bb                   Ram Lakhan
# 40  661eabc123abc123abc123bb              Andaz Apna Apna
# 41  661eabc123abc123abc123bb                       Tezaab
# 42  661eabc123abc123abc123bb                    Mr. India
# 43  661eabc123abc123abc123bb                          War
# 44  661eabc123abc123abc123bb                      Dhoom 2
# 45  661eabc123abc123abc123bb                       Judaai
# 46  661eabc123abc123abc123cc            Bareilly Ki Barfi
# 47  661eabc123abc123abc123cc                     2 States
# 48  661eabc123abc123abc123cc  Dilwale Dulhania Le Jayenge
# 49  661eabc123abc123abc123cc     Kabhi Khushi Kabhie Gham
# 50  661eabc123abc123abc123cc           Kuch Kuch Hota Hai
# 51  661eabc123abc123abc123cc                  Luka Chuppi
# 52  661eabc123abc123abc123cc      Yeh Jawaani Hai Deewani
# 53  661eabc123abc123abc123cc                         Mimi
# 54  661eabc123abc123abc123cc             Dil To Pagal Hai
# 55  661eabc123abc123abc123cc                      Hum Tum
# 56  67ff7f0c88982068ff3e8fe0           Omkara (2006 film)
# 57  67ff7f0c88982068ff3e8fe0               Company (film)
# 58  67fcab79c055d149ee6dca28                     Gol Maal
# 59  67fcab79c055d149ee6dca29                     2 States

# %%
# ✅ Create user-movie matrix
user_movie_matrix = pd.crosstab(df['user'], df['title'])
user_movie_matrix
# Out:
# title                     2 States  Andaz Apna Apna  Article 15  \
# user
# 661eabc123abc123abc123aa         0                0           1
# 661eabc123abc123abc123bb         0                1           0
# 661eabc123abc123abc123cc         1                0           0
# 67fcab79c055d149ee6dca27         0                0           0
# 67fcab79c055d149ee6dca28         0                0           0
# 67fcab79c055d149ee6dca29         1                0           0
# 67ff7f0c88982068ff3e8fe0         0                0           0
#
# title                     Bareilly Ki Barfi  Beta  Bhoot (film)  \
# user
# 661eabc123abc123abc123aa                  0     0             0
# 661eabc123abc123abc123bb                  0     1             0
# 661eabc123abc123abc123cc                  1     0             0
# 67fcab79c055d149ee6dca27                  0     0             2
# 67fcab79c055d149ee6dca28                  0     0             0
# 67fcab79c055d149ee6dca29                  0     0             0
# 67ff7f0c88982068ff3e8fe0                  0     0             0
#
# title                     Black Friday (2007 film)  Chhalia  Company (film)  \
# user
# 661eabc123abc123abc123aa                         0        0               0
# 661eabc123abc123abc123bb                         0        0               0
# 661eabc123abc123abc123cc                         0        0               0
# 67fcab79c055d149ee6dca27                         2        1               0
# 67fcab79c055d149ee6dca28                         0        0               0
# 67fcab79c055d149ee6dca29                         0        0               0
# 67ff7f0c88982068ff3e8fe0                         0        0               1
#
# title                     Dehraadun Diary  ...  Section 375  Shamitabh  \
# user                                       ...
# 661eabc123abc123abc123aa                0  ...            0          0
# 661eabc123abc123abc123bb                0  ...            0          0
# 661eabc123abc123abc123cc                0  ...            0          0
# 67fcab79c055d149ee6dca27                1  ...            3          1
# 67fcab79c055d149ee6dca28                0  ...            0          0
# 67fcab79c055d149ee6dca29                0  ...            0          0
# 67ff7f0c88982068ff3e8fe0                0  ...            0          0
#
# title                     Talvar  Tezaab  Uri  Uri: The Surgical Strike  \
# user
# 661eabc123abc123abc123aa       1       0    1                         0
# 661eabc123abc123abc123bb       0       1    0                         0
# 661eabc123abc123abc123cc       0       0    0                         0
# 67fcab79c055d149ee6dca27       0       0    0                         2
# 67fcab79c055d149ee6dca28       0       0    0                         0
# 67fcab79c055d149ee6dca29       0       0    0                         0
# 67ff7f0c88982068ff3e8fe0       0       0    0                         0
#
# title                     Vishwaroopam  War  Welcome  Yeh Jawaani Hai Deewani
# user
# 661eabc123abc123abc123aa             0    0        0                        0
# 661eabc123abc123abc123bb             0    1        1                        0
# 661eabc123abc123abc123cc             0    0        0                        1
# 67fcab79c055d149ee6dca27             1    0        0                        0
# 67fcab79c055d149ee6dca28             0    0        0                        0
# 67fcab79c055d149ee6dca29             0    0        0                        0
# 67ff7f0c88982068ff3e8fe0             0    0        0                        0
#
# [7 rows x 47 columns]

# %%
# ✅ Compute cosine similarity
user_similarity = cosine_similarity(user_movie_matrix)
user_similarity_df = pd.DataFrame(user_similarity, index=user_movie_matrix.index, columns=user_movie_matrix.index)

# %%
# ✅ Function to recommend movies to a user
def recommend_movies_for_user(target_user_id, top_n_similar_users=5):
    if target_user_id not in user_similarity_df.index:
        return f"User {target_user_id} not found."
    
    # Get similar users
    similar_users = user_similarity_df[target_user_id].sort_values(ascending=False)[1:top_n_similar_users+1].index
    
    # Movies watched by similar users but not by target user
    target_user_movies = set(df[df['user'] == target_user_id]['title'])
    recommendations = set()
    
    for user in similar_users:
        user_movies = set(df[df['user'] == user]['title'])
        recommendations.update(user_movies - target_user_movies)
    
    return sorted(recommendations)

# %%
# ✅ Example: Recommend movies for a specific user
target_user = df['user'].iloc[1]  # Or any known user ID from the DataFrame
recommend_movies_for_user(target_user)
# Out:
# ['2 States',
#  'Andaz Apna Apna',
#  'Article 15',
#  'Bareilly Ki Barfi',
#  'Beta',
#  'Dhoom 2',
#  'Dil To Pagal Hai',
#  'Dilwale Dulhania Le Jayenge',
#  'Hum Tum',
#  'Judaai',
#  'Kabhi Khushi Kabhie Gham',
#  'Kahaani',
#  'Kuch Kuch Hota Hai',
#  'Luka Chuppi',
#  'Masaan',
#  'Mimi',
#  'Mr. India',
#  'October',
#  'Pathaan',
#  'Piku',
#  'Raazi',
#  'Ram Lakhan',
#  'Rang De Basanti',
#  'Sardar Udham',
#  'Talvar',
#  'Tezaab',
#  'Uri',
#  'War',
#  'Welcome',
#  'Yeh Jawaani Hai Deewani']

# %%
def recommend_movies_for_user(target_user_id, top_n_similar_users=5):

    MONGO_URI = "mongodb+srv://admin:Ananya%402801@cluster0.jann4mj.mongodb.net/movie_recommender?retryWrites=true&w=majority&tls=true"
    client = MongoClient(MONGO_URI)
    db = client["movie_recommender"]
    history_collection = db["histories"]

    data = list(history_collection.find())
    df = pd.DataFrame(data)

    df = df.drop(columns=['_id', 'timestamp', '__v'], errors='ignore')

    df['user'] = df['user'].astype(str)

    user_movie_matrix = pd.crosstab(df['user'], df['title'])
    # user_movie_matrix

    user_similarity = cosine_similarity(user_movie_matrix)
    user_similarity_df = pd.DataFrame(user_similarity, index=user_movie_matrix.index, columns=user_movie_matrix.index)
    
    if target_user_id not in user_similarity_df.index:
        return f"User {target_user_id} not found."
    
    # Get similar users
    similar_users = user_similarity_df[target_user_id].sort_values(ascending=False)[1:top_n_similar_users+1].index
    
    # Movies watched by similar users but not by target user
    target_user_movies = set(df[df['user'] == target_user_id]['title'])
    recommendations = set()
    
    for user in similar_users:
        user_movies = set(df[df['user'] == user]['title'])
        recommendations.update(user_movies - target_user_movies)
    
    return sorted(recommendations)

# %%
# ✅ Example: Recommend movies for a specific user
recommend_movies_for_user('67fcab79c055d149ee6dca29')
# Out:
# ['Andaz Apna Apna',
#  'Article 15',
#  'Bareilly Ki Barfi',
#  'Beta',
#  'Bhoot (film)',
#  'Black Friday (2007 film)',
#  'Chhalia',
#  'Dehraadun Diary',
#  'Dhoom 2',
#  'Dil To Pagal Hai',
#  'Dilwale Dulhania Le Jayenge',
#  'Gol Maal',
#  'Hum Tum',
#  'Jaane Bhi Do Yaaro',
#  'Judaai',
#  'Kabhi Khushi Kabhie Gham',
#  'Kahaani',
#  'Kuch Kuch Hota Hai',
#  'Kuchh Bheege Alfaaz',
#  'Love Marriage (1959 film)',
#  'Luka Chuppi',
#  'Marmayogi',
#  'Masaan',
#  'Mimi',
#  'Mr. India',
#  'OMG – Oh My God!',
#  'October',
#  'Pathaan',
#  'Piku',
#  'Raazi',
#  'Ram Lakhan',
#  'Ranchi Diaries',
#  'Rang De Basanti',
#  'Sardar Udham',
#  'Section 375',
#  'Shamitabh',
#  'Talvar',
#  'Tezaab',
#  'Uri',
#  'Uri: The Surgical Strike',
#  'Vishwaroopam',
#  'War',
#  'Welcome',
#  'Yeh Jawaani Hai Deewani']

# %%
from datetime import datetime
from bson import ObjectId

db.histories.insert_one({
    "user": ObjectId("67fcab79c055d149ee6dca29"),
    "title": "2 States",
    "timestamp": datetime.utcnow()  # ✅ colon, not equals
})
# Out:
# InsertOneResult(ObjectId('6803cc22d4d1a84ab85786e3'), acknowledged=True)

# %%
item_similarity_df
# Out:
# title                        2 States  Andaz Apna Apna  Article 15  \
# title
# 2 States                     1.000000              0.0         0.0
# Andaz Apna Apna              0.000000              1.0         0.0
# Article 15                   0.000000              0.0         1.0
# Bareilly Ki Barfi            0.707107              0.0         0.0
# Beta                         0.000000              1.0         0.0
# Bhoot (film)                 0.000000              0.0         0.0
# Black Friday (2007 film)     0.000000              0.0         0.0
# Chhalia                      0.000000              0.0         0.0
# Company (film)               0.000000              0.0         0.0
# Dehraadun Diary              0.000000              0.0         0.0
# Dhoom 2                      0.000000              1.0         0.0
# Dil To Pagal Hai             0.707107              0.0         0.0
# Dilwale Dulhania Le Jayenge  0.707107              0.0         0.0
# Gol Maal                     0.000000              0.0         0.0
# Hum Tum                      0.707107              0.0         0.0
# Jaane Bhi Do Yaaro           0.000000              0.0         0.0
# Judaai                       0.000000              1.0         0.0
# Kabhi Khushi Kabhie Gham     0.707107              0.0         0.0
# Kahaani                      0.000000              0.0         1.0
# Kuch Kuch Hota Hai           0.707107              0.0         0.0
# Kuchh Bheege Alfaaz          0.000000              0.0         0.0
# Love Marriage (1959 film)    0.000000              0.0         0.0
# Shamitabh                             0.000000   0.0      1.000000
# Talvar                                0.000000   0.0      0.000000
# Tezaab                                0.000000   1.0      0.000000
# Uri                                   0.000000   0.0      0.000000
# Uri: The Surgical Strike              0.000000   0.0      1.000000
# Vishwaroopam                          0.000000   0.0      1.000000
# War                                   0.000000   1.0      0.000000
# Welcome                               0.000000   1.0      0.000000
# Yeh Jawaani Hai Deewani               1.000000   0.0      0.000000
#
# title                        Black Friday (2007 film)   Chhalia  \
# title
# 2 States                                     0.000000  0.000000
# Andaz Apna Apna                              0.000000  0.000000
# Article 15                                   0.000000  0.000000
# Bareilly Ki Barfi                            0.000000  0.000000
# Beta                                         0.000000  0.000000
# Bhoot (film)                                 1.000000  1.000000
# Black Friday (2007 film)                     1.000000  1.000000
# Chhalia                                      1.000000  1.000000
# Company (film)                               0.000000  0.000000
# Dehraadun Diary                              1.000000  1.000000
# Dhoom 2                                      0.000000  0.000000
# Dil To Pagal Hai                             0.000000  0.000000
# Dilwale Dulhania Le Jayenge                  0.000000  0.000000
# Gol Maal                                     0.894427  0.894427
# Hum Tum                                      0.000000  0.000000
# Jaane Bhi Do Yaaro                           1.000000  1.000000
# Judaai                                       0.000000  0.000000
# Kabhi Khushi Kabhie Gham                     0.000000  0.000000
# Kahaani                                      0.000000  0.000000
# Kuch Kuch Hota Hai                           0.000000  0.000000
# Kuchh Bheege Alfaaz                          1.000000  1.000000
# Love Marriage (1959 film)                    1.000000  1.000000
# Luka Chuppi                                  0.000000  0.000000
# Marmayogi                                    1.000000  1.000000
# Masaan                                       0.000000  0.000000
# Mimi                                         0.000000  0.000000
# Mr. India                                    0.000000  0.000000
# OMG – Oh My God!                             1.000000  1.000000
# October                                      0.000000  0.000000
# Omkara (2006 film)                           0.000000  0.000000
# Pathaan                                      0.000000  0.000000
# Piku                                         0.000000  0.000000
# Raazi                                        0.000000  0.000000
# Ram Lakhan                                   0.000000  0.000000
# Ranchi Diaries                               1.000000  1.000000
# Rang De Basanti                              0.000000  0.000000
# Sardar Udham                                 0.000000  0.000000
# Section 375                                  1.000000  1.000000
# Shamitabh                                    1.000000  1.000000
# Talvar                                       0.000000  0.000000
# Tezaab                                       0.000000  0.000000
# Uri                                          0.000000  0.000000
# Uri: The Surgical Strike                     1.000000  1.000000
# Vishwaroopam                                 1.000000  1.000000
# War                                          0.000000  0.000000
# Welcome                                      0.000000  0.000000
# Yeh Jawaani Hai Deewani                      0.000000  0.000000
#
# title                        Company (film)  Dehraadun Diary  ...  \
# title                                                         ...
# 2 States                                0.0         0.000000  ...
# Andaz Apna Apna                         0.0         0.000000  ...
# Article 15                              0.0         0.000000  ...
# Bareilly Ki Barfi                       0.0         0.000000  ...
# Beta                                    0.0         0.000000  ...
# Bhoot (film)                            0.0         1.000000  ...
# Black Friday (2007 film)                0.0         1.000000  ...
# Chhalia                                 0.0         1.000000  ...
# Company (film)                          1.0         0.000000  ...
# Dehraadun Diary                         0.0         1.000000  ...
# Dhoom 2                                 0.0         0.000000  ...
# Dil To Pagal Hai                        0.0         0.000000  ...
# Dilwale Dulhania Le Jayenge             0.0         0.000000  ...
# Gol Maal                                0.0         0.894427  ...
# Hum Tum                                 0.0         0.000000  ...
# Jaane Bhi Do Yaaro                      0.0         1.000000  ...
# Judaai                                  0.0         0.000000  ...
# Kabhi Khushi Kabhie Gham                0.0         0.000000  ...
# Kahaani                                 0.0         0.000000  ...
# Kuch Kuch Hota Hai                      0.0         0.000000  ...
# Kuchh Bheege Alfaaz                     0.0         1.000000  ...
# Love Marriage (1959 film)               0.0         1.000000  ...
# Luka Chuppi                             0.0         0.000000  ...
# Marmayogi                               0.0         1.000000  ...
# Masaan                                  0.0         0.000000  ...
# Mimi                                    0.0         0.000000  ...
# Mr. India                               0.0         0.000000  ...
# OMG – Oh My God!                        0.0         1.000000  ...
# October                                 0.0         0.000000  ...
# Omkara (2006 film)                      1.0         0.000000  ...
# Pathaan                                 0.0         0.000000  ...
# Piku                                    0.0         0.000000  ...
# Raazi                                   0.0         0.000000  ...
# Ram Lakhan                              0.0         0.000000  ...
# Ranchi Diaries                          0.0         1.000000  ...
# Rang De Basanti                         0.0         0.000000  ...
# Sardar Udham                            0.0         0.000000  ...
# Section 375                             0.0         1.000000  ...
# Shamitabh                               0.0         1.000000  ...
# Talvar                                  0.0         0.000000  ...
# Tezaab                                  0.0         0.000000  ...
# Uri                                     0.0         0.000000  ...
# Uri: The Surgical Strike                0.0         1.000000  ...
# Vishwaroopam                            0.0         1.000000  ...
# War                                     0.0         0.000000  ...
# Welcome                                 0.0         0.000000  ...
# Yeh Jawaani Hai Deewani                 0.0         0.000000  ...
#
# title                        Section 375  Shamitabh  Talvar  Tezaab  Uri  \
# title
# 2 States                        0.000000   0.000000     0.0     0.0  0.0
# Andaz Apna Apna                 0.000000   0.000000     0.0     1.0  0.0
# Article 15                      0.000000   0.000000     1.0     0.0  1.0
# Bareilly Ki Barfi               0.000000   0.000000     0.0     0.0  0.0
# Beta                            0.000000   0.000000     0.0     1.0  0.0
# Bhoot (film)                    1.000000   1.000000     0.0     0.0  0.0
# Black Friday (2007 film)        1.000000   1.000000     0.0     0.0  0.0
# Chhalia                         1.000000   1.000000     0.0     0.0  0.0
# Company (film)                  0.000000   0.000000     0.0     0.0  0.0
# Dehraadun Diary                 1.000000   1.000000     0.0     0.0  0.0
# Dhoom 2                         0.000000   0.000000     0.0     1.0  0.0
# Dil To Pagal Hai                0.000000   0.000000     0.0     0.0  0.0
# Dilwale Dulhania Le Jayenge     0.000000   0.000000     0.0     0.0  0.0
# Gol Maal                        0.894427   0.894427     0.0     0.0  0.0
# Hum Tum                         0.000000   0.000000     0.0     0.0  0.0
# Jaane Bhi Do Yaaro              1.000000   1.000000     0.0     0.0  0.0
# Judaai                          0.000000   0.000000     0.0     1.0  0.0
# Kabhi Khushi Kabhie Gham        0.000000   0.000000     0.0     0.0  0.0
# Kahaani                         0.000000   0.000000     1.0     0.0  1.0
# Kuch Kuch Hota Hai              0.000000   0.000000     0.0     0.0  0.0
# %%
def recommend_similar_movies(movie_title, top_n=15, threshold=0.5):
    """
    Recommends movies similar to the given movie title based on item-item similarity,
    with a minimum similarity threshold.
    
    Parameters:
        movie_title (str): Title of the reference movie.
        top_n (int): Maximum number of similar movies to return.
        threshold (float): Minimum similarity score to consider.
    
    Returns:
        list: List of recommended movie titles above the threshold.
    """
    if movie_title not in item_similarity_df.index:
        return f"❌ Movie '{movie_title}' not found in similarity matrix."

    # Get similarity scores, drop the movie itself
    similar_scores = item_similarity_df[movie_title].sort_values(ascending=False)
    print(similar_scores)

    # Filter scores above threshold
    filtered_scores = similar_scores[similar_scores > threshold]
    print(filtered_scores)

    # Sort and return top N titles
    recommended = filtered_scores.sort_values(ascending=False).head(top_n).index.tolist()
    
    return recommended

# %%
# Test the function
recommend_similar_movies("2 States")  # replace with any movie title from your DB
# Out:
# title
# 2 States                       1.000000
# Dil To Pagal Hai               0.707107
# Mimi                           0.707107
# Luka Chuppi                    0.707107
# Kuch Kuch Hota Hai             0.707107
# Kabhi Khushi Kabhie Gham       0.707107
# Hum Tum                        0.707107
# Dilwale Dulhania Le Jayenge    0.707107
# Yeh Jawaani Hai Deewani        0.707107
# Bareilly Ki Barfi              0.707107
# Dehraadun Diary                0.000000
# Section 375                    0.000000
# Piku                           0.000000
# Raazi                          0.000000
# Ram Lakhan                     0.000000
# Ranchi Diaries                 0.000000
# Rang De Basanti                0.000000
# Sardar Udham                   0.000000
# Shamitabh                      0.000000
# Omkara (2006 film)             0.000000
# Talvar                         0.000000
# Tezaab                         0.000000
# Uri                            0.000000
# Uri: The Surgical Strike       0.000000
# Vishwaroopam                   0.000000
# War                            0.000000
# Welcome                        0.000000
# Pathaan                        0.000000
# October                        0.000000
# Dhoom 2                        0.000000
# OMG – Oh My God!               0.000000
# Company (film)                 0.000000
# Chhalia                        0.000000
# Gol Maal                       0.000000
# Black Friday (2007 film)       0.000000
# Jaane Bhi Do Yaaro             0.000000
# Judaai                         0.000000
# Bhoot (film)                   0.000000
# Kahaani                        0.000000
# Beta                           0.000000
# Kuchh Bheege Alfaaz            0.000000
# Love Marriage (1959 film)      0.000000
# Andaz Apna Apna                0.000000
# Masaan                         0.000000
# Article 15                     0.000000
# Mr. India                      0.000000
# Marmayogi                      0.000000
# Name: 2 States, dtype: float64
# title
# 2 States                       1.000000
# Dil To Pagal Hai               0.707107
# Mimi                           0.707107
# Luka Chuppi                    0.707107
# Kuch Kuch Hota Hai             0.707107
# Kabhi Khushi Kabhie Gham       0.707107
# Hum Tum                        0.707107
# Dilwale Dulhania Le Jayenge    0.707107
# Yeh Jawaani Hai Deewani        0.707107
# Bareilly Ki Barfi              0.707107
# Name: 2 States, dtype: float64
# ['2 States',
#  'Dil To Pagal Hai',
#  'Mimi',
#  'Luka Chuppi',
#  'Kuch Kuch Hota Hai',
#  'Kabhi Khushi Kabhie Gham',
#  'Hum Tum',
#  'Dilwale Dulhania Le Jayenge',
#  'Yeh Jawaani Hai Deewani',
#  'Bareilly Ki Barfi']
