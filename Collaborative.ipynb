# %%
# ✅ Import libraries
from pymongo import MongoClient
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
# ✅ Connect to MongoDB Atlas
MONGO_URI = "mongodb+srv://admin:Ananya%402801@cluster0.jann4mj.mongodb.net/movie_recommender?retryWrites=true&w=majority&tls=true"
client = MongoClient(MONGO_URI)
db = client["movie_recommender"]
collection = db["histories"]

# %%
# ✅ Load data
data = list(collection.find())
df = pd.DataFrame(data)

# %%
# ✅ Drop irrelevant columns
df = df.drop(columns=['_id', 'timestamp', '__v'], errors='ignore')

# %%
# ✅ Convert ObjectId to string for 'user'
df['user'] = df['user'].astype(str)

# %%
df
# Out:
#                         user                        title
# 0   67fcab79c055d149ee6dca27             OMG – Oh My God!
# 1   67fcab79c055d149ee6dca27             OMG – Oh My God!
# 2   67fcab79c055d149ee6dca27     Uri: The Surgical Strike
# 3   67fcab79c055d149ee6dca27     Uri: The Surgical Strike
# 4   67fcab79c055d149ee6dca27     Black Friday (2007 film)
# 5   67fcab79c055d149ee6dca27     Black Friday (2007 film)
# 6   67fcab79c055d149ee6dca27                     Gol Maal
# 7   67fcab79c055d149ee6dca27                     Gol Maal
# 8   67fcab79c055d149ee6dca27           Jaane Bhi Do Yaaro
# 9   67fcab79c055d149ee6dca27           Jaane Bhi Do Yaaro
# 10  67fcab79c055d149ee6dca27               Ranchi Diaries
# 11  67fcab79c055d149ee6dca27               Ranchi Diaries
# 12  67fcab79c055d149ee6dca27    Love Marriage (1959 film)
# 13  67fcab79c055d149ee6dca27    Love Marriage (1959 film)
# 14  67fcab79c055d149ee6dca27    Love Marriage (1959 film)
# 15  67fcab79c055d149ee6dca27                    Marmayogi
# 16  67fcab79c055d149ee6dca27          Kuchh Bheege Alfaaz
# 17  67fcab79c055d149ee6dca27                      Chhalia
# 18  67fcab79c055d149ee6dca27                 Bhoot (film)
# 19  67fcab79c055d149ee6dca27                 Bhoot (film)
# 20  67fcab79c055d149ee6dca27                  Section 375
# 21  67fcab79c055d149ee6dca27                  Section 375
# 22  67fcab79c055d149ee6dca27                  Section 375
# 23  67fcab79c055d149ee6dca27              Dehraadun Diary
# 24  67fcab79c055d149ee6dca27                    Shamitabh
# 25  67fcab79c055d149ee6dca27                 Vishwaroopam
# 26  661eabc123abc123abc123aa                        Raazi
# 27  661eabc123abc123abc123aa                          Uri
# 28  661eabc123abc123abc123aa                       Talvar
# 29  661eabc123abc123abc123aa                         Piku
# 30  661eabc123abc123abc123aa                 Sardar Udham
# 31  661eabc123abc123abc123aa                      Kahaani
# 32  661eabc123abc123abc123aa              Rang De Basanti
# 33  661eabc123abc123abc123aa                      October
# 34  661eabc123abc123abc123aa                   Article 15
# 35  661eabc123abc123abc123aa                       Masaan
# 36  661eabc123abc123abc123bb                          War
# 37  661eabc123abc123abc123bb                      Pathaan
# 38  661eabc123abc123abc123bb                      Welcome
# 39  661eabc123abc123abc123bb                      Dhoom 2
# 40  661eabc123abc123abc123bb                       Judaai
# 41  661eabc123abc123abc123bb              Andaz Apna Apna
# 42  661eabc123abc123abc123bb                       Tezaab
# 43  661eabc123abc123abc123bb                         Beta
# 44  661eabc123abc123abc123bb                    Mr. India
# 45  661eabc123abc123abc123bb                   Ram Lakhan
# 46  661eabc123abc123abc123cc  Dilwale Dulhania Le Jayenge
# 47  661eabc123abc123abc123cc      Yeh Jawaani Hai Deewani
# 48  661eabc123abc123abc123cc            Bareilly Ki Barfi
# 49  661eabc123abc123abc123cc                  Luka Chuppi
# 50  661eabc123abc123abc123cc                         Mimi
# 51  661eabc123abc123abc123cc     Kabhi Khushi Kabhie Gham
# 52  661eabc123abc123abc123cc             Dil To Pagal Hai
# 53  661eabc123abc123abc123cc           Kuch Kuch Hota Hai
# 54  661eabc123abc123abc123cc                      Hum Tum
# 55  661eabc123abc123abc123cc                     2 States

# %%
# ✅ Create user-movie matrix
user_movie_matrix = pd.crosstab(df['user'], df['title'])
user_movie_matrix
# Out:
# title                     2 States  Andaz Apna Apna  Article 15  \
# user
# 661eabc123abc123abc123aa         0                0           1
# 661eabc123abc123abc123bb         0                1           0
# 661eabc123abc123abc123cc         1                0           0
# 67fcab79c055d149ee6dca27         0                0           0
#
# title                     Bareilly Ki Barfi  Beta  Bhoot (film)  \
# user
# 661eabc123abc123abc123aa                  0     0             0
# 661eabc123abc123abc123bb                  0     1             0
# 661eabc123abc123abc123cc                  1     0             0
# 67fcab79c055d149ee6dca27                  0     0             2
#
# title                     Black Friday (2007 film)  Chhalia  Dehraadun Diary  \
# user
# 661eabc123abc123abc123aa                         0        0                0
# 661eabc123abc123abc123bb                         0        0                0
# 661eabc123abc123abc123cc                         0        0                0
# 67fcab79c055d149ee6dca27                         2        1                1
#
# title                     Dhoom 2  ...  Section 375  Shamitabh  Talvar  \
# user                               ...
# 661eabc123abc123abc123aa        0  ...            0          0       1
# 661eabc123abc123abc123bb        1  ...            0          0       0
# 661eabc123abc123abc123cc        0  ...            0          0       0
# 67fcab79c055d149ee6dca27        0  ...            3          1       0
#
# title                     Tezaab  Uri  Uri: The Surgical Strike  Vishwaroopam  \
# user
# 661eabc123abc123abc123aa       0    1                         0             0
# 661eabc123abc123abc123bb       1    0                         0             0
# 661eabc123abc123abc123cc       0    0                         0             0
# 67fcab79c055d149ee6dca27       0    0                         2             1
#
# title                     War  Welcome  Yeh Jawaani Hai Deewani
# user
# 661eabc123abc123abc123aa    0        0                        0
# 661eabc123abc123abc123bb    1        1                        0
# 661eabc123abc123abc123cc    0        0                        1
# 67fcab79c055d149ee6dca27    0        0                        0
#
# [4 rows x 45 columns]

# %%
# ✅ Compute cosine similarity
user_similarity = cosine_similarity(user_movie_matrix)
user_similarity_df = pd.DataFrame(user_similarity, index=user_movie_matrix.index, columns=user_movie_matrix.index)

# %%
# ✅ Function to recommend movies to a user
def recommend_movies_for_user(target_user_id, top_n_similar_users=5):
    if target_user_id not in user_similarity_df.index:
        return f"User {target_user_id} not found."
    
    # Get similar users
    similar_users = user_similarity_df[target_user_id].sort_values(ascending=False)[1:top_n_similar_users+1].index
    
    # Movies watched by similar users but not by target user
    target_user_movies = set(df[df['user'] == target_user_id]['title'])
    recommendations = set()
    
    for user in similar_users:
        user_movies = set(df[df['user'] == user]['title'])
        recommendations.update(user_movies - target_user_movies)
    
    return sorted(recommendations)

# %%
# ✅ Example: Recommend movies for a specific user
target_user = df['user'].iloc[1]  # Or any known user ID from the DataFrame
recommend_movies_for_user(target_user)
# Out:
# ['2 States',
#  'Andaz Apna Apna',
#  'Article 15',
#  'Bareilly Ki Barfi',
#  'Beta',
#  'Dhoom 2',
#  'Dil To Pagal Hai',
#  'Dilwale Dulhania Le Jayenge',
#  'Hum Tum',
#  'Judaai',
#  'Kabhi Khushi Kabhie Gham',
#  'Kahaani',
#  'Kuch Kuch Hota Hai',
#  'Luka Chuppi',
#  'Masaan',
#  'Mimi',
#  'Mr. India',
#  'October',
#  'Pathaan',
#  'Piku',
#  'Raazi',
#  'Ram Lakhan',
#  'Rang De Basanti',
#  'Sardar Udham',
#  'Talvar',
#  'Tezaab',
#  'Uri',
#  'War',
#  'Welcome',
#  'Yeh Jawaani Hai Deewani']

# %%
# ✅ Create movie-user matrix (transpose of user-movie)
movie_user_matrix = pd.crosstab(df['title'], df['user'])

# %%
# ✅ Compute item-item cosine similarity
item_similarity = cosine_similarity(movie_user_matrix)
item_similarity_df = pd.DataFrame(item_similarity, index=movie_user_matrix.index, columns=movie_user_matrix.index)

# %%
def recommend_similar_movies(movie_title, top_n=5):
    """
    Recommends movies similar to the given movie title based on item-item similarity.
    
    Parameters:
        movie_title (str): Title of the reference movie.
        top_n (int): Number of similar movies to return.
    
    Returns:
        list: List of recommended movie titles.
    """
    if movie_title not in item_similarity_df.index:
        return f"❌ Movie '{movie_title}' not found in similarity matrix."

    # Get similarity scores and sort them
    similar_scores = item_similarity_df[movie_title].sort_values(ascending=False)

    # Skip the movie itself (first one), return top_n similar movies
    recommended = similar_scores.iloc[1:top_n+1].index.tolist()

    return recommended

# %%
# Test the function
recommend_similar_movies("2 States")  # replace with any movie title from your DB
# Out:
# ['Dil To Pagal Hai',
#  'Mimi',
#  'Luka Chuppi',
#  'Kuch Kuch Hota Hai',
#  'Kabhi Khushi Kabhie Gham']

# %%
with open('user_similarity.pkl', 'wb') as f:
    pickle.dump(user_similarity_df, f)

# %%
with open('item_similarity.pkl', 'wb') as f:
    pickle.dump(user_similarity_df, f)
